# %%
import sqlite3

# Connect to a database (or create it if it doesn't exist)
conn = sqlite3.connect('dialects_database.db')

# %%
# Create a cursor object to execute SQL commands
cursor = conn.cursor()

# Query the information schema to get tables and their columns
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table in tables:
    print("Table:", table[0])
    cursor.execute("PRAGMA table_info('{}');".format(table[0]))
    columns = cursor.fetchall()
    print("Columns:")
    for column in columns:
        print(column)
    

# Close the connection
# Out:
# Table: id_text
# Columns:
# (0, 'id', 'INTEGER', 0, None, 0)
# (1, 'text', 'TEXT', 0, None, 0)
# Table: id_dialect
# Columns:
# (0, 'id', 'INTEGER', 0, None, 0)
# (1, 'dialect', 'TEXT', 0, None, 0)

# %%
import pandas as pd
import sqlite3

#Fetch the data from a specific table (assuming the table name is 'dialects')
query = " SELECT * FROM id_text "
df_id_text = pd.read_sql_query(query, conn)
df_id_text
# Out:
#                          id                                               text
# 0       1009754958479151232  @toha_Altomy @gy_yah قليلين ادب ومنافقين. لو ا...
# 1       1009794751548313600  @AlmFaisal 😂😂 الليبيين متقلبين!!!\nبس بالنسبة ...
# 2       1019989115490787200  @smsm071990 @ALMOGRBE كل 20 تانيه شاب ليبي بير...
# 3       1035479791758135168  @AboryPro @lyranoo85 رانيا عقليتك متخلفة. اولا...
# 4       1035481122921164800  @lyranoo85 شكلك متعقدة علشان الراجل لي تحبيه ا...
# ...                     ...                                                ...
# 147720   982775354405376000  الناس دي بتنفخ في قربة مقدودة بالدارجي كده  ال...
# 147721   980728852224860160  @Wail_Hamza @amiromer انت عايش وين بره السودان...
# 147722   975502734668500992  مااحرم نفسي ميسي حريف ولعاب برضو ..\nمدريدي وا...
# 147723   980207908641263616  ياخي ديل ماخلو  للشيطان وإبليس شي لكن يروحو وي...
# 147724   981080482380238848     @abdomaged127 النبي فيك صدمتني ياخي عاوز تعويض
#
# ...

# %%
#Fetch the data from a specific table (assuming the table name is 'dialects')
query = " SELECT * FROM id_dialect "
df_id_dialect = pd.read_sql_query(query, conn)
df_id_dialect
# Out:
#                          id dialect
# 0       1009754958479151232      LY
# 1       1009794751548313600      LY
# 2       1019989115490787200      LY
# 3       1035479791758135168      LY
# 4       1035481122921164800      LY
# ...                     ...     ...
# 147720   982775354405376000      SD
# 147721   980728852224860160      SD
# 147722   975502734668500992      SD
# 147723   980207908641263616      SD
# 147724   981080482380238848      SD
#
# [147725 rows x 2 columns]

# %%
query = " SELECT dialect , text FROM id_dialect JOIN id_text ON id_text.id = id_dialect.id  "
df= pd.read_sql_query(query, conn)
df
# Out:
#        dialect                                               text
# 0           LY  @toha_Altomy @gy_yah قليلين ادب ومنافقين. لو ا...
# 1           LY  @AlmFaisal 😂😂 الليبيين متقلبين!!!\nبس بالنسبة ...
# 2           LY  @smsm071990 @ALMOGRBE كل 20 تانيه شاب ليبي بير...
# 3           LY  @AboryPro @lyranoo85 رانيا عقليتك متخلفة. اولا...
# 4           LY  @lyranoo85 شكلك متعقدة علشان الراجل لي تحبيه ا...
# ...        ...                                                ...
# 147720      SD  الناس دي بتنفخ في قربة مقدودة بالدارجي كده  ال...
# 147721      SD  @Wail_Hamza @amiromer انت عايش وين بره السودان...
# 147722      SD  مااحرم نفسي ميسي حريف ولعاب برضو ..\nمدريدي وا...
# 147723      SD  ياخي ديل ماخلو  للشيطان وإبليس شي لكن يروحو وي...
# 147724      SD     @abdomaged127 النبي فيك صدمتني ياخي عاوز تعويض
#
# [147725 rows x 2 columns]

# %%
df.to_csv('dialect_text.csv', index=False)  # 'output.csv' is the name of the CSV file you want to save
